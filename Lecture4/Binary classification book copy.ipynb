# %%
# Import libraries
import torch
import torch.nn as nn
import numpy as np
from torch.utils.data import DataLoader, TensorDataset
from torch.optim import RMSprop
from sklearn.datasets import make_classification
from sklearn.model_selection import train_test_split

import torch.optim as optim

import random

# Function to set the seed
#def set_seed(seed):
#    torch.manual_seed(seed)
#    torch.cuda.manual_seed(seed)
#    torch.cuda.manual_seed_all(seed)
#    np.random.seed(seed)
#    random.seed(seed)
#    torch.backends.cudnn.deterministic = True
#    torch.backends.cudnn.benchmark = False

#set_seed(42)

torch.manual_seed(0)
np.random.seed(0)

# Create training and test sets
features, target = make_classification(n_classes=2, n_features=10,
n_samples=1000)
features_train, features_test, target_train, target_test = train_test_split(
features, target, test_size=0.1, random_state=1)




# Convert data to PyTorch tensors
x_train = torch.from_numpy(features_train).float()
y_train = torch.from_numpy(target_train).float().view(-1, 1)
x_test = torch.from_numpy(features_test).float()
y_test = torch.from_numpy(target_test).float().view(-1, 1)


# Define a neural network using `Sequential`
class SimpleNeuralNet(nn.Module):
    def __init__(self):
        super(SimpleNeuralNet, self).__init__()
        self.sequential = torch.nn.Sequential(
            torch.nn.Linear(10, 16),
            torch.nn.ReLU(),
            torch.nn.Linear(16,16),
            torch.nn.ReLU(),
            torch.nn.Linear(16, 1),
            torch.nn.Sigmoid()
        )
    def forward(self, x):
        x = self.sequential(x)
        return x

# Initialize neural network
network = SimpleNeuralNet()
# Define loss function, optimizer
criterion = nn.BCELoss()
optimizer = RMSprop(network.parameters())

# Define data loader
train_data = TensorDataset(x_train, y_train)
train_loader = DataLoader(train_data, batch_size=100, shuffle=True)
# Compile the model using torch 2.0's optimizer
network = torch.compile(network)

#import torch._dynamo
#torch._dynamo.config.suppress_errors = True

# Train neural network
epochs = 3
for epoch in range(epochs):
    for batch_idx, (data, target) in enumerate(train_loader):
        optimizer.zero_grad()
        output = network(data)
        loss = criterion(output, target)
        loss.backward()
        optimizer.step()
    print("Epoch:", epoch+1, "\tLoss:", loss.item())
# Evaluate neural network

with torch.no_grad():
    output = network(x_test)
    test_loss = criterion(output, y_test)
    test_accuracy = (output.round() == y_test).float().mean()
    print("Test Loss:", test_loss.item(), "\tTest Accuracy:",
        test_accuracy.item())
# Out:
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824] WON'T CONVERT forward C:\Users\tdiak_000\AppData\Local\Temp\ipykernel_22240\2126035803.py line 57
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824] due to:
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824] Traceback (most recent call last):
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 786, in _convert_frame
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     result = inner_convert(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]              ^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 400, in _convert_frame_assert
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return _compile(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\contextlib.py", line 81, in inner
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return func(*args, **kwds)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 676, in _compile
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\utils.py", line 262, in time_wrapper
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     r = func(*args, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]         ^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 535, in compile_inner
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     out_code = transform_code_object(code, transform)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1036, in transform_code_object
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     transformations(instructions, code_options)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 165, in _fn
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return fn(*args, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 500, in transform
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     tracer.run()
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2149, in run
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     super().run()
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 810, in run
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     and self.step()
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]         ^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 773, in step
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     getattr(self, inst.opname)(inst)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2268, in RETURN_VALUE
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     self.output.compile_subgraph(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 971, in compile_subgraph
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\contextlib.py", line 81, in inner
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return func(*args, **kwds)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 1168, in compile_and_call_fx_graph
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     compiled_fn = self.call_user_compiler(gm)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\utils.py", line 262, in time_wrapper
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     r = func(*args, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]         ^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 1241, in call_user_compiler
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 1222, in call_user_compiler
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 117, in debug_wrapper
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     compiled_gm = compiler_fn(gm, example_inputs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\__init__.py", line 1729, in __call__
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\contextlib.py", line 81, in inner
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return func(*args, **kwds)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 1330, in compile_fx
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return aot_autograd(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\backends\common.py", line 58, in compiler_fn
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     cg = aot_module_simplified(gm, example_inputs, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_functorch\aot_autograd.py", line 903, in aot_module_simplified
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     compiled_fn = create_aot_dispatcher_function(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\utils.py", line 262, in time_wrapper
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     r = func(*args, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]         ^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_functorch\aot_autograd.py", line 628, in create_aot_dispatcher_function
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     compiled_fn = compiler_fn(flat_fn, fake_flat_args, aot_config, fw_metadata=fw_metadata)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_functorch\_aot_autograd\runtime_wrappers.py", line 443, in aot_wrapper_dedupe
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return compiler_fn(flat_fn, leaf_flat_args, aot_config, fw_metadata=fw_metadata)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_functorch\_aot_autograd\runtime_wrappers.py", line 648, in aot_wrapper_synthetic_base
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return compiler_fn(flat_fn, flat_args, aot_config, fw_metadata=fw_metadata)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 352, in aot_dispatch_autograd
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\utils.py", line 262, in time_wrapper
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     r = func(*args, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]         ^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 1257, in fw_compiler_base
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return inner_compile(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 83, in debug_wrapper
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_inductor\debug.py", line 304, in inner
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return fn(*args, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\contextlib.py", line 81, in inner
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return func(*args, **kwds)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\contextlib.py", line 81, in inner
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return func(*args, **kwds)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\utils.py", line 262, in time_wrapper
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     r = func(*args, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]         ^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 438, in compile_fx_inner
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     compiled_graph = fx_codegen_and_compile(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 714, in fx_codegen_and_compile
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     compiled_fn = graph.compile_to_fn()
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                   ^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_inductor\graph.py", line 1307, in compile_to_fn
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return self.compile_to_module().call
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\utils.py", line 262, in time_wrapper
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     r = func(*args, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]         ^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_inductor\graph.py", line 1254, in compile_to_module
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     mod = PyCodeCache.load_by_key_path(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_inductor\codecache.py", line 2154, in load_by_key_path
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     raise RuntimeError(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824] RuntimeError: Failed to import C:\Users\TDIAK_~1\AppData\Local\Temp\torchinductor_tdiak_000\gb\cgbxakxk4ncithknzcgipwjsmiida3tgncar6gwgejtwqrbqs56w.py
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824] SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 13-14: truncated \UXXXXXXXX escape (cgbxakxk4ncithknzcgipwjsmiida3tgncar6gwgejtwqrbqs56w.py, line 42)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824] Traceback (most recent call last):
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 786, in _convert_frame
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     result = inner_convert(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]              ^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 400, in _convert_frame_assert
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return _compile(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\contextlib.py", line 81, in inner
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return func(*args, **kwds)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 676, in _compile
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     guarded_code = compile_inner(code, one_graph, hooks, transform)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                    ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\utils.py", line 262, in time_wrapper
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     r = func(*args, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]         ^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 535, in compile_inner
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     out_code = transform_code_object(code, transform)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\bytecode_transformation.py", line 1036, in transform_code_object
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     transformations(instructions, code_options)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 165, in _fn
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return fn(*args, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\convert_frame.py", line 500, in transform
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     tracer.run()
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2149, in run
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     super().run()
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 810, in run
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     and self.step()
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]         ^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 773, in step
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     getattr(self, inst.opname)(inst)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\symbolic_convert.py", line 2268, in RETURN_VALUE
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     self.output.compile_subgraph(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 971, in compile_subgraph
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     self.compile_and_call_fx_graph(tx, list(reversed(stack_values)), root)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\contextlib.py", line 81, in inner
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return func(*args, **kwds)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 1168, in compile_and_call_fx_graph
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     compiled_fn = self.call_user_compiler(gm)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\utils.py", line 262, in time_wrapper
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     r = func(*args, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]         ^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 1241, in call_user_compiler
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     raise BackendCompilerFailed(self.compiler_fn, e).with_traceback(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\output_graph.py", line 1222, in call_user_compiler
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     compiled_fn = compiler_fn(gm, self.example_inputs())
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\repro\after_dynamo.py", line 117, in debug_wrapper
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     compiled_gm = compiler_fn(gm, example_inputs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\__init__.py", line 1729, in __call__
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return compile_fx(model_, inputs_, config_patches=self.config)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\contextlib.py", line 81, in inner
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return func(*args, **kwds)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 1330, in compile_fx
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return aot_autograd(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\backends\common.py", line 58, in compiler_fn
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     cg = aot_module_simplified(gm, example_inputs, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]          ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_functorch\aot_autograd.py", line 903, in aot_module_simplified
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     compiled_fn = create_aot_dispatcher_function(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\utils.py", line 262, in time_wrapper
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     r = func(*args, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]         ^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_functorch\aot_autograd.py", line 628, in create_aot_dispatcher_function
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     compiled_fn = compiler_fn(flat_fn, fake_flat_args, aot_config, fw_metadata=fw_metadata)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                   ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_functorch\_aot_autograd\runtime_wrappers.py", line 443, in aot_wrapper_dedupe
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return compiler_fn(flat_fn, leaf_flat_args, aot_config, fw_metadata=fw_metadata)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_functorch\_aot_autograd\runtime_wrappers.py", line 648, in aot_wrapper_synthetic_base
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return compiler_fn(flat_fn, flat_args, aot_config, fw_metadata=fw_metadata)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_functorch\_aot_autograd\jit_compile_runtime_wrappers.py", line 352, in aot_dispatch_autograd
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     compiled_fw_func = aot_config.fw_compiler(fw_module, adjusted_flat_args)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                        ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\utils.py", line 262, in time_wrapper
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     r = func(*args, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]         ^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 1257, in fw_compiler_base
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return inner_compile(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\repro\after_aot.py", line 83, in debug_wrapper
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     inner_compiled_fn = compiler_fn(gm, example_inputs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                         ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_inductor\debug.py", line 304, in inner
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return fn(*args, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\contextlib.py", line 81, in inner
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return func(*args, **kwds)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\contextlib.py", line 81, in inner
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return func(*args, **kwds)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\utils.py", line 262, in time_wrapper
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     r = func(*args, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]         ^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 438, in compile_fx_inner
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     compiled_graph = fx_codegen_and_compile(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                      ^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_inductor\compile_fx.py", line 714, in fx_codegen_and_compile
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     compiled_fn = graph.compile_to_fn()
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]                   ^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_inductor\graph.py", line 1307, in compile_to_fn
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     return self.compile_to_module().call
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]            ^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_dynamo\utils.py", line 262, in time_wrapper
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     r = func(*args, **kwargs)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]         ^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_inductor\graph.py", line 1254, in compile_to_module
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     mod = PyCodeCache.load_by_key_path(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]           ^^^^^^^^^^^^^^^^^^^^^^^^^^^^^
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]   File "C:\Users\tdiak_000\anaconda3\Lib\site-packages\torch\_inductor\codecache.py", line 2154, in load_by_key_path
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]     raise RuntimeError(
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824] torch._dynamo.exc.BackendCompilerFailed: backend='inductor' raised:
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824] RuntimeError: Failed to import C:\Users\TDIAK_~1\AppData\Local\Temp\torchinductor_tdiak_000\gb\cgbxakxk4ncithknzcgipwjsmiida3tgncar6gwgejtwqrbqs56w.py
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824] SyntaxError: (unicode error) 'unicodeescape' codec can't decode bytes in position 13-14: truncated \UXXXXXXXX escape (cgbxakxk4ncithknzcgipwjsmiida3tgncar6gwgejtwqrbqs56w.py, line 42)
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824] Set TORCH_LOGS="+dynamo" and TORCHDYNAMO_VERBOSE=1 for more information
# W0618 09:38:52.250000 8808 torch\_dynamo\convert_frame.py:824]
# Epoch: 1 	Loss: 0.19006989896297455
# Epoch: 2 	Loss: 0.14092369377613068
# Epoch: 3 	Loss: 0.03935525193810463
# Test Loss: 0.06877756118774414 	Test Accuracy: 0.9700000286102295
